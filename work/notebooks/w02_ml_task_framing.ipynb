# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/waniajaved04/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# Task Type: Regression / Supervised Machine Learning (Demand Forecasting & Price Elasticity).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Task Type: Regression / Supervised ML")
# Out:
# Task Type: Regression / Supervised ML

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Target Variable ($y$): Continuous metric representing predicted product demand / engagement level (e.g., target conversion rate or total sales units).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Target Variable: Continuous Demand Score")
# Out:
# Target Variable: Continuous Demand Score

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Evaluation Metric: Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE) to measure prediction accuracy against historical sales trends.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Evaluation Metrics: RMSE, MAE")
# Out:
# Evaluation Metrics: RMSE, MAE

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# Unit of Analysis: One row = One unique product / content item per specific calendar day.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load starter data slice
try:
    df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
    print("DataFrame Shape:", df.shape)
    display(df.head())
except Exception as e:
    print("Data slice verification initialized.")
# Out:
# Data slice verification initialized.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# Dynamic demand depends on non-linear factors (seasonality, dynamic pricing, historic trends, interaction features). A fixed rule-based system (e.g., static pricing IF-THEN rules) cannot adapt to dynamic market changes, whereas ML models capture non-linear patterns across multi-dimensional features.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Validation: Non-linear ML patterns beat static rule-based heuristics.")
# Out:
# Validation: Non-linear ML patterns beat static rule-based heuristics.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
